# %% [markdown]
# <a href="https://colab.research.google.com/github/sarthaksirvaiya/241b230/blob/main/Lab_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Warshall algorithm to find reachability between all pairs of vertices in a graph.
# Problem Description:
# Understand transitive closure of a graph. Use Python to compute reachability using matrix method.

# %% [markdown]
# #Theory
# Warshall algorithm finds whether a path exists between every pair of vertices. It updates the adjacency matrix step by step. If there is a path from i to j through k, then the entry becomes 1.
#
# ## Algorithm
# 1. Represent graph using adjacency matrix.
# 2. For each intermediate vertex k
# 3. Check all pairs i and j
# 4. Update value if path exists through k
# 4. Repeat for all vertices

# %%
def warshall(graph):

    n = len(graph)

    for k in range(n):
        for i in range(n):
            for j in range(n):
                graph[i][j] = graph[i][j] or (graph[i][k] and graph[k][j])

    return graph

# %%
n = int(input("Enter the number of vertices: "))
graph = []
print(f"Enter the {n}x{n} adjacency matrix:")
for i in range(n):
    while True:
        try:
            row_str = input(f"Enter row {i + 1}: ")
            row = list(map(int, row_str.split()))
            if len(row) != n:
                print(f"Error: Row must contain exactly {n}")
            elif not all(x in [0, 1] for x in row):
                print("Matrix values must be 0 or 1")
            else:
                graph.append(row)
                break
        except ValueError:
            print("Invalid input")
print("Input Graph:")
for row in graph:
    print(row)
import copy
initial_graph = copy.deepcopy(graph)
result = warshall(initial_graph)
print("\nTransitive Closure Matrix (Reachability):")
print("   ", end="")
for j in range(len(result[0])):
    print(f"{j+1} ", end="")
print()
for i in range(len(result)):
    print(f"{i+1}: ", end="")
    for j in range(len(result[0])):
        print(f"{result[i][j]} ", end="")
    print()
# Out:
# Enter the number of vertices: 2
# Enter the 2x2 adjacency matrix:
# Enter row 1: 0 1
# Enter row 2: 1 0
# Input Graph:
# [0, 1]
# [1, 0]
#
# Transitive Closure Matrix (Reachability):
#    1 2
# 1: 1 1
# 2: 1 1

# %% [markdown]
# Now, let's implement
# 1. Modify program to take matrix input from user
# 2. Apply algorithm on graph with 5 vertices
# 3. Compare Warshall with Floyd algorithm
# 4. Display path existence in readable format

# %% [markdown]
# ## Find shortest paths between all pairs of vertices using Floyd Warshall algorithm.

# %%
INF = float('inf')
def parse_weight(val_str):
    if val_str.lower() == 'inf':
        return INF
    try:
        return int(val_str)
    except ValueError:
        raise ValueError("Invalid input")
n = int(input("Enter the number of vertices for Floyd-Warshall: "))
graph_fw = []
print(f"Enter the {n}x{n} weighted adjacency matriX")
for i in range(n):
    while True:
        try:
            row_str = input(f"Enter row {i + 1}: ")
            values_str = row_str.split()
            if len(values_str) != n:
                print(f"Row must contain exactly {n} values")
            else:
                row_fw = [parse_weight(v) for v in values_str]
                graph_fw.append(row_fw)
                break
        except ValueError as e:
            print("Invalid input")

print("\nInput Graph for Floyd-Warshall:")
for row in graph_fw:
    print(row)
result_fw = floyd_warshall(graph_fw)

print("\nShortest distance matrix (Floyd-Warshall):")
for row in result_fw:
    print(row)
# Out:
# Enter the number of vertices for Floyd-Warshall: 2
# Enter the 2x2 weighted adjacency matriX
# Enter row 1: 1 0
# Enter row 2: 0 1
#
# Input Graph for Floyd-Warshall:
# [1, 0]
# [0, 1]
#
# Shortest distance matrix (Floyd-Warshall):
# [0, 0]
# [0, 0]

# %% [markdown]
# #Understand all pairs shortest path problem. Implement dynamic programming approach in Python.
#
# * Given a weighted graph with positive or negative edge weights, find
# shortest distances between every pair of vertices.

# %% [markdown]
# # Theory
# Floyd Warshall algorithm computes shortest paths between all pairs of nodes. It updates the distance matrix by checking if a shorter path exists through an intermediate vertex. Works with negative weights but fails with negative cycles.
#
# Algorithm
# 1. Represent graph using distance matrix.
# 2. Initialize matrix with given weights.
# 3. Set distance of node to itself as 0.
# 4. For each intermediate vertex k
# 5. Update distance[i][j] = min(distance[i][j], distance[i][k] + distance[k][j])
# 6. Repeat for all vertices

# %%
def floyd_warshall(graph):

    n = len(graph)

    dist = []
    for i in range(n):
        dist.append(graph[i][:])

    for k in range(n):
        for i in range(n):
            for j in range(n):
                if dist[i][k] + dist[k][j] < dist[i][j]:
                    dist[i][j] = dist[i][k] + dist[k][j]

    return dist

# %% [markdown]
# # Excercise
# 1. Take matrix input from user
# 2. Detect negative cycle in graph
# 3. Print shortest path between two given vertices
# 4. Compare with Dijkstra algorithm
